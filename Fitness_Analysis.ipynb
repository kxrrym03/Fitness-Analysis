# %% [markdown]
# <a href="https://colab.research.google.com/github/kxrrym03/Fitness-Analysis/blob/main/Fitness_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6a35bd4a-2bef-414a-ada6-3227381ee2ee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6a35bd4a-2bef-414a-ada6-3227381ee2ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('random_fitness_dataset.csv')
df.shape
# Out:
# (200, 12)

# %%
df.head()
# Out:
#    record_id            timestamp user_id  age  gender      activity_type  \
# 0          1  2025-07-22 09:22:54    U026   67    Male            Cycling
# 1          2  2025-05-28 13:53:54    U039   16  Female  Strength Training
# 2          3  2025-08-07 01:36:54    U046   62  Female            Cycling
# 3          4  2025-07-17 01:56:54    U048   56  Female           Swimming
# 4          5  2025-08-11 03:22:54    U042   42   Other               Yoga
#
#    duration_min  calories_burned  heart_rate_avg  steps  sleep_hours  \
# 0             7              322             175   3591          7.0
# 1            83              265             113  22312          5.7
# 2           118              508              98   5418          6.6
# 3            75              270             150  19809          7.9
# 4            76              308             141  12562          5.0
#
#    weight_kg
# 0       84.3
# 1       79.6
# 2       88.3
# 3       69.0
# 4       61.6

# %%
df.tail()
# Out:
#      record_id            timestamp user_id  age  gender      activity_type  \
# 195        196  2025-05-28 13:00:54    U011   62  Female               Yoga
# 196        197  2025-10-10 22:31:54    U045   17    Male               Yoga
# 197        198  2025-06-12 04:53:54    U021   41   Other  Strength Training
# 198        199  2025-10-11 21:37:54    U009   66   Other               Yoga
# 199        200  2025-07-11 04:47:54    U027   44   Other            Running
#
#      duration_min  calories_burned  heart_rate_avg  steps  sleep_hours  \
# 195            84              435             130  18532          6.8
# 196            65              408              73   8355          4.2
# 197            99              585              89  22822          8.0
# 198            74              230              72  16001          4.3
# 199            68              241              80   7358          7.4
#
#      weight_kg
# 195       46.2
# 196       89.4
# 197       59.3
# ...

# %%
df.columns
# Out:
# Index(['record_id', 'timestamp', 'user_id', 'age', 'gender', 'activity_type',
#        'duration_min', 'calories_burned', 'heart_rate_avg', 'steps',
#        'sleep_hours', 'weight_kg'],
#       dtype='object')

# %%
df.describe()
# Out:
#         record_id         age  duration_min  calories_burned  heart_rate_avg  \
# count  200.000000  200.000000    200.000000       200.000000      200.000000
# mean   100.500000   44.380000     64.025000       295.765000      120.935000
# std     57.879185   15.417982     34.693987       120.563834       34.100366
# min      1.000000   16.000000      5.000000        50.000000       60.000000
# 25%     50.750000   33.000000     33.000000       220.000000       89.750000
# 50%    100.500000   43.000000     68.000000       311.500000      121.000000
# 75%    150.250000   58.000000     95.000000       378.000000      150.250000
# max    200.000000   69.000000    119.000000       585.000000      179.000000
#
#              steps  sleep_hours   weight_kg
# count    200.00000   200.000000  200.000000
# mean   14020.82000     6.313000   70.152000
# std     6428.05981     1.911518   14.129562
# min      370.00000     3.000000   35.300000
# 25%     9585.00000     4.775000   61.450000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   record_id        200 non-null    int64
#  1   timestamp        200 non-null    object
#  2   user_id          200 non-null    object
#  3   age              200 non-null    int64
#  4   gender           200 non-null    object
#  5   activity_type    200 non-null    object
#  6   duration_min     200 non-null    int64
#  7   calories_burned  200 non-null    int64
#  8   heart_rate_avg   200 non-null    int64
#  9   steps            200 non-null    int64
#  10  sleep_hours      200 non-null    float64
#  11  weight_kg        200 non-null    float64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 18.9+ KB

# %%
df.isnull().sum()
# Out:
# record_id          0
# timestamp          0
# user_id            0
# age                0
# gender             0
# activity_type      0
# duration_min       0
# calories_burned    0
# heart_rate_avg     0
# steps              0
# sleep_hours        0
# weight_kg          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Visualizations

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='activity_type')
plt.title('Distribution of Activity Types')
plt.xticks(rotation=270)
plt.xlabel('Activity Type')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.countplot(data=df, x='gender')
plt.title('Distribution of Gender')
plt.xticks(rotation=270)
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])
df['timestamp'] = df['timestamp'].dt.date
df.head()
# Out:
#    record_id   timestamp user_id  age  gender      activity_type  \
# 0          1  2025-07-22    U026   67    Male            Cycling
# 1          2  2025-05-28    U039   16  Female  Strength Training
# 2          3  2025-08-07    U046   62  Female            Cycling
# 3          4  2025-07-17    U048   56  Female           Swimming
# 4          5  2025-08-11    U042   42   Other               Yoga
#
#    duration_min  calories_burned  heart_rate_avg  steps  sleep_hours  \
# 0             7              322             175   3591          7.0
# 1            83              265             113  22312          5.7
# 2           118              508              98   5418          6.6
# 3            75              270             150  19809          7.9
# 4            76              308             141  12562          5.0
#
#    weight_kg
# 0       84.3
# 1       79.6
# 2       88.3
# 3       69.0
# 4       61.6

# %%
df_sorted = df.sort_values(by='timestamp')
df_sorted['steps_rolling_avg'] = df_sorted['steps'].rolling(window=7).mean()

plt.figure(figsize=(12, 6))
sns.lineplot(data=df_sorted, x='timestamp', y='steps', label='Daily Steps', alpha=0.6)
sns.lineplot(data=df_sorted, x='timestamp', y='steps_rolling_avg', label='7-Day Rolling Average')

plt.title('Steps over Time with Rolling Average')
plt.xlabel('Timestamp')
plt.ylabel('Steps')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
avg_calories_burned_by_activity = df.groupby('activity_type')['calories_burned'].mean().reset_index()
print("Average Calories Burned by Activity Type:")
print(avg_calories_burned_by_activity)
# Out:
# Average Calories Burned by Activity Type:
#        activity_type  calories_burned
# 0            Cycling       250.478261
# 1               HIIT       320.629630
# 2            Running       302.833333
# 3  Strength Training       267.444444
# 4           Swimming       286.925926
# 5            Walking       304.033333
# 6               Yoga       318.523810

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=avg_calories_burned_by_activity, x='activity_type', y='calories_burned')
plt.title('Average Calories Burned by Activity Type')
plt.xlabel('Activity Type')
plt.ylabel('Average Calories Burned')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
average_weight_by_gender = df.groupby('gender')['weight_kg'].mean().reset_index()
print("Average Weight (kg) by Gender:")
print(average_weight_by_gender)
# Out:
# Average Weight (kg) by Gender:
#    gender  weight_kg
# 0  Female  70.550725
# 1    Male  71.049206
# 2   Other  68.916176

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=average_weight_by_gender, x='gender', y='weight_kg', palette='viridis')
plt.title('Average Weight (kg) by Gender')
plt.xlabel('Gender')
plt.ylabel('Average Weight (kg)')
plt.tight_layout()
plt.show()

# %%
avg_duration_by_activity = df.groupby('activity_type')['duration_min'].mean().reset_index()
print("Average Duration (minutes) by Activity Type:")
print(avg_duration_by_activity)
# Out:
# Average Duration (minutes) by Activity Type:
#        activity_type  duration_min
# 0            Cycling     58.782609
# 1               HIIT     60.481481
# 2            Running     64.583333
# 3  Strength Training     64.370370
# 4           Swimming     71.888889
# 5            Walking     59.700000
# 6               Yoga     66.666667

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=avg_duration_by_activity, x='activity_type', y='duration_min', palette='muted')
plt.title('Average Duration (minutes) by Activity Type')
plt.xlabel('Activity Type')
plt.ylabel('Average Duration (minutes)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 7))
sns.countplot(data=df, x='activity_type', hue='gender', palette='viridis')
plt.title('Distribution of Activity Types per Gender')
plt.xlabel('Activity Type')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Gender')
plt.tight_layout()
plt.show()
